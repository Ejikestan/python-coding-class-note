# %% [markdown]
# # A Quick Tour of Variables and Data Types in Python
#
#
# ![](https://i.imgur.com/6cg2E9Q.png)
# These tutorials take a practical and coding-focused approach. The best way to learn the material is to execute the code and experiment with it yourself.

# %%
my_favorite_color = "blue"

# %%
my_favorite_color
# Out:
# 'blue'

# %%
color1, color2, color3 = "red", "purple", "blue"

# %%
print(color1)
print(color2)
print(color3)
# Out:
# red
# purple
# blue

# %%
color4 = color5 = color6 = "magenta"

# %%
print(color4)
print(color5)
print(color6)
# Out:
# magenta
# magenta
# magenta

# %%
counter = 10

# %%
counter = counter + 1

# %%
counter
# Out:
# 11

# %%
counter = 10

# %%
counter += 1

# %%
counter
# Out:
# 11

# %%
counter = None
print(counter)
# Out:
# None

# %% [markdown]
# Class Assessment
#
# define a variable and assign None to it, increase the value of that variable by 5 and print its answer.

# %%
counter = None

counter += 5
print(counter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13842/1158446454.py in <cell line: 0>()
#       1 counter = None
#       2
# ----> 3 counter += 5
#       4 print(counter)
#
# TypeError: unsupported operand type(s) for +=: 'NoneType' and 'int'

# %%
counter = 0 
counter += 5
print(counter)
# Out:
# 5

# %%
a_variable = 23
is_today_Saturday = False
my_favorite_car = "Benz"
the_3_musketeers = ["Athos", "Porthos", "Aramis"] #A list

# %%
a_variable
# Out:
# 23

# %%
type(a_variable)
# Out:
# int

# %%
is_today_Saturday
# Out:
# False

# %%
type(is_today_Saturday)
# Out:
# bool

# %%
city = "Akure"
type(city)
# Out:
# str

# %%
type(the_3_musketeers)
# Out:
# list

# %%
a_list = ["toy", 1, None, -200, 3.156, False]
print(a_list)
type(a_list)
# Out:
# ['toy', 1, None, -200, 3.156, False]
# list

# %% [markdown]
# Python has several built-in data types for storing different kinds of information in variables. Following are some commonly used data types:
#
# 1. Integer
# 2. Float
# 3. Boolean
# 4. None
# 5. String
# 6. List
# 7. Tuple
# 8. Dictionary
#
# Integer, float, boolean, None, and string are *primitive data types* because they represent a single value. Other data types like list, tuple, and dictionary are often called *data structures* or *containers* because they hold multiple pieces of data together.

# %% [markdown]
# ### Integer
#
# Integers represent positive or negative whole numbers, from negative infinity to infinity. Note that integers should not include decimal points. Integers have the type `int`.

# %%
current_year = 2026

# %%
print(current_year)
# Out:
# 2026

# %%
type(current_year)
# Out:
# int

# %%
a_large_negative_number = -23374038374832934334234317348343

# %%
type(a_large_negative_number)
# Out:
# int

# %% [markdown]
# ### Float
#
# Floats (or floating-point numbers) are numbers with a decimal point. There are no limits on the value or the number of digits before or after the decimal point. Floating-point numbers have the type `float`.

# %%
22/7
# Out:
# 3.142857142857143

# %%
pi = 3.142857142857143

# %%
type(pi)
# Out:
# float

# %% [markdown]
# Note that a whole number is treated as a float if written with a decimal point, even though the decimal portion of the number is zero.

# %%
a_number = 2.0

# %%
type(a_number)
# Out:
# float

# %%
another_number = 4.

# %%
type(another_number)
# Out:
# float

# %% [markdown]
# Floating point numbers can also be written using the scientific notation with an "e" to indicate the power of 10.

# %%
one_hundredth = 1/100
print(one_hundredth)
# Out:
# 0.01

# %%
one_hundredth = 1e-2
print(one_hundredth)
# Out:
# 0.01

# %%
type(one_hundredth)
# Out:
# float

# %%
avogradro_number = 6.02214076e23
print(avogradro_number)
# Out:
# 6.02214076e+23

# %%
type(avogradro_number)
# Out:
# float

# %% [markdown]
# You can convert floats into integers and vice versa using the `float` and `int` functions. The operation of converting one type of value into another is called casting.

# %%
current_year = 2026
print(current_year)
type(current_year)
# Out:
# 2026
# int

# %%
# convert integer to float using float function.

year = float(current_year)
year
# Out:
# 2026.0

# %%
a_large_negative_number = -23374038374832934334234317348343
type(a_large_negative_number)
# Out:
# int

# %%
float(a_large_negative_number)
# Out:
# -2.3374038374832935e+31

# %%
-2.3374038374832935 * (10**31)
# Out:
# -2.3374038374832935e+31

# %%
float(1000000000000123440987634734800)
# Out:
# 1.0000000000001234e+30

# %% [markdown]
# While performing arithmetic operations, integers are automatically converted to `float`s if any of the operands is a `float`. Also, the division operator `/` always returns a `float`, even if both operands are integers. Use the `//` operator if you want the result of the division to be an `int`.

# %%
45 * 3.0
# Out:
# 135.0

# %%
45+3.0
# Out:
# 48.0

# %%
2/1
# Out:
# 2.0

# %%
5/2
# Out:
# 2.5

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %%
2//1
# Out:
# 2

# %%
5//2
# Out:
# 2

# %% [markdown]
# Booloan
#
# Boolean represent one of two values, True or False.
#
# Boolean havce the type bool.

# %%
is_today_saturday = True

# %%
is_today_saturday
# Out:
# True

# %%
type(is_today_saturday)
# Out:
# bool

# %% [markdown]
# Booleans are generally the result of a comparison operation, e.g., `==`, `>=`, etc.

# %%
cost_of_ice_bag = 200

is_ice_bag_expensive = cost_of_ice_bag > 150
print(is_ice_bag_expensive)
# Out:
# True

# %% [markdown]
# Booleans are automatically converted to `int`s when used in arithmetic operations. `True` is converted to `1` and `False` is converted to `0`.

# %%
2 + True
# Out:
# 3

# %%
5.0 + False
# Out:
# 5.0

# %%
a = -1000
type(a)
# Out:
# int

# %%
b = -1000.0
type(b)
# Out:
# float

# %% [markdown]
# Floating point numbers can also be written using the scientific notation with an "e" to indicate the power of 10.

# %%
result = (512 - 282) / (47 * 48 + 5)
print(f"My result is {result:.4f}")
# Out:
# My result is 0.1017

# %%
x = input("Enter your number here: ")
print(x)
type(x)
# Out:
# 5
# str

# %%
number = int(input("Enter a number: "))
square = number ** 2
print(f"The square of {number} is {square}.")
# Out:
# The square of 5 is 25.

# %% [markdown]
# 6. Ask the user to put down a number x, use the sep optional argument to print out x, 2x, 3x, 4x, and 5x, each seperated by three dashes

# %%
# x = input("enter here: ")

# convert back to integer

x = int(input("Enter the number here"))
# print(type(x))

print(x, 2*x, 3*x, 4*x, 5*x, sep=" --- ")
# Out:
# 3 --- 6 --- 9 --- 12 --- 15

# %% [markdown]
# 7. write a program that asks user for a weight in kilograms and convert it to pounds
#
# NOTE: There are 2.2pounds in 1 Kilogram.

# %%
kg = float(input("Enter your weight in kg: "))

pounds = kg * 2.2

print(f"Your weight in pounds is {pounds:.3f}lb")
# Out:
# Your weight in pounds is 140.140lb

# %% [markdown]
# 8. Write a program that asks the user to enter three numbers (use seperate input statements). create variable called total and average of the three numbers and print out the values of total and average.

# %%
number1 = float(input("Enter first number here: "))
number2= float(input("Enter second number here: "))
number3 = float(input("Enter third number here: "))

sum = number1 + number2 + number3

average = sum/3

print(f"The total of the three numbers is {sum} while the average of the numbers is {average}")
# Out:
# The total of the three numbers is 9.0 while the average of the numbers is 3.0

# %% [markdown]
# 9. A lot of cell phones have tip calculators. Write one. Ask the user the price of the meal and the percent tip they want to leave. then print both tip amount and the total bill with the tip included.

# %% [markdown]
# On your phone, open chrome. and type this below:
#
# https://colab.research.google.com/

# %% [markdown]
# Any value in Python can be converted to a Boolean using the `bool` function.
#
# Only the following values evaluate to `False` (they are often called *falsy* values):
#
# 1. The value `False` itself
# 2. The integer `0`
# 3. The float `0.0`
# 4. The empty value `None`
# 5. The empty text `""`
# 6. The empty list `[]`
# 7. The empty tuple `()`
# 8. The empty dictionary `{}`
# 9. The empty set `set()`
# 10. The empty range `range(0)`
#
# Everything else evaluates to `True` (a value that evaluates to `True` is often called a *truthy* value).

# %%
num = set([1, 2, 3, 4, 4])
num
# Out:
# {1, 2, 3, 4}

# %%
type(num)
# Out:
# set

# %%
# "" - A string that has nothing in it is called an empty string.

# %%
print(bool(False))
print(bool(0))
print(bool(None))
print(bool(""))
print(bool([]))
print(bool(()))
print(bool({}))
print(bool(set()))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False

# %%
a_list = [1, 2, 3, 4]

if bool(a_list) == False:
    print("Nothing in list")
else:
    print("List is not empty")
# Out:
# List is not empty

# %%
bool(True), bool(1), bool(2.0), bool("hello, i love python"), bool([1, 2]), bool((2, 3))
# Out:
# (True, True, True, True, True, True)

# %% [markdown]
# ### None
#
# The None type includes a single value `None`, used to indicate the absence of a value. `None` has the type `NoneType`. It is often used to declare a variable whose value may be assigned later.

# %%
nothing = None

type(nothing)
# Out:
# NoneType

# %% [markdown]
# ### String
#
# A string is used to represent text (*a string of characters*) in Python. Strings must be surrounded using quotations (either the single quote `'` or the double quote `"`). Strings have the type `string`.

# %%
today = "Sunday"
print(today)
# Out:
# Sunday

# %%
type(today)
# Out:
# str

# %% [markdown]
# You can use single or double quotes inside a string

# %%
my_favorite_movie = 'Home a"lone'
print(my_favorite_movie)
another_movie = "One Flew over the Cuckoo's Nest"
print(another_movie)
# Out:
# Home a"lone
# One Flew over the Cuckoo's Nest

# %%
movie = 'Slum dog milli\'onaire'
print(movie)
# Out:
# Slum dog milli'onaire

# %% [markdown]
# # Multi-line string
#
# Strings created using single or double quotes must begin and end on the same line. To create multiline strings, use three single quotes `'''` or three double quotes `"""` to begin and end the string. Line breaks are represented using the newline character `\n`.

# %%
a_joke = """
Son: "Dad, can you tell me what a solar eclipse is?"
Dad: "No sun."
"""

print(a_joke)
# Out:
# Son: "Dad, can you tell me what a solar eclipse is?"
# Dad: "No sun."

# %%
# \n creates a new line.

print('Testing out\nA new line')
# Out:
# Testing out
# A new line

# %% [markdown]
# You can check the length of a string using the `len` function.

# %%
text = "hello"
print("The number of characters in text is", len(text))
# Out:
# The number of characters in text is 5

# %% [markdown]
# A string can be converted into a list of characters using `list` function.

# %%
text = """a
b"""
text
len(text)
# Out:
# 3

# %%
list(text)
# Out:
# ['a', '\n', 'b']

# %% [markdown]
# Strings also support several list operations, which are discussed in the next section. We'll look at a couple of examples here.
#
# You can access individual characters within a string using the `[]` indexing notation. Note the character indices go from `0` to `n-1`, where `n` is the length of the string.

# %%
today
# Out:
# 'Sunday'

# %%
today[0]
# Out:
# 'S'

# %%
today[5]
# Out:
# 'y'

# %% [markdown]
# You can access a part of a string using by providing a `start:end` range instead of a single index in `[]`.

# %%
today[3:6]
# Out:
# 'day'

# %%
date = 'Monday is great'

date[10:15]
# Out:
# 'great'

# %%
drink = "Coca-cola"
drink[5:9]
# Out:
# 'cola'

# %%
drink[0:4]
# Out:
# 'Coca'

# %%
drink[:4]
# Out:
# 'Coca'

# %%
drink[5:]
# Out:
# 'cola'

# %% [markdown]
# Concartenation in python means merging two or more strings together.
#
# this is achieved using the `+` operator.

# %%
drink[0:4] + drink[5:9]
# Out:
# 'Cocacola'

# %%
'Kemi' + 'Kareem'
# Out:
# 'KemiKareem'

# %%
today
# Out:
# 'Sunday'

# %%
"sun" in today
# Out:
# False

# %%
"day" in today
# Out:
# True

# %%
print("Hello" + " "+"Trump" + "!")
# Out:
# Hello Trump!

# %% [markdown]
# Strings in Python have many built-in *methods* that are used to manipulate them. Let's try out some common string methods.
#
# > **Methods**: Methods are functions associated with data types and are accessed using the `.` notation e.g. `variable_name.method()` or `"a string".method()`. Methods are a powerful technique for associating common operations with values of specific data types.
#
# The `.lower()`, `.upper()` and `.capitalize()` methods are used to change the case of the characters.

# %%
today
# Out:
# 'Sunday'

# %%
# using lowercase method

today.lower()
# Out:
# 'sunday'

# %%
# using uppercase method

today.upper()
# Out:
# 'SUNDAY'

# %%
today.capitalize()
# Out:
# 'Sunday'
